# %%
from tensorflow.keras.datasets import mnist
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
(train_images,train_labels),(test_images,test_labels)= mnist.load_data()

# %%
#train images shape
train_images.shape
# Out:
# (60000, 28, 28)

# %%
#train_labels shape
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
#test images shape
test_images.shape
# Out:
# (10000, 28, 28)

# %%
#test labels shape
test_labels.shape
# Out:
# (10000,)

# %% [markdown]
# ## Network Architecture

# %%
#creating a model i.e sequential model
model = models.Sequential()
#add dense layer to model with relu activation
model.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
#add Dense layer to model with softmax activation 
#Dense layer-fully connected
model.add(layers.Dense(10,activation='softmax'))

# %% [markdown]
# ### Relu activation
# ![relu activation](relu.png)
# g ( z ) = max { 0 , z }

# %% [markdown]
# ## Compilation step

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## Preparing the image data

# %%
train_images = train_images.reshape((60000,28*28))
#astype-casting a pandas object to float32 datatype
train_images = train_images.astype('float32')/255
test_images = test_images.reshape((10000,28*28))
test_images = test_images.astype('float32')/255

# %% [markdown]
# ## Preparing the labels

# %%
from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
model.fit(train_images,train_labels,epochs=5,batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 3s 5ms/step - loss: 0.4401 - accuracy: 0.8722
# Epoch 2/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1158 - accuracy: 0.9647
# Epoch 3/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0736 - accuracy: 0.9776
# Epoch 4/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0498 - accuracy: 0.9846
# Epoch 5/5
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0353 - accuracy: 0.9893

# %%
test_loss,test_acc = model.evaluate(test_images,test_labels)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0646 - accuracy: 0.9802

# %%
print("test accuracy : ",test_acc*100)
# Out:
# test accuracy :  98.01999926567078
